# %% [markdown]
# ## Naufal irbah

# %%
import cv2
import numpy

# %%
image = cv2.imread('LafazAllah.jpeg')
image = cv2.resize(image, None, fx=0.3,fy=0.3)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
ret, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
contours, hierarchy = cv2.findContours(binary, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_NONE)

# %%
print("Length of contours {}".format(len(contours)))
print(contours)
# Out:
# Length of contours 778
# (array([[[0, 0]],
#
#        [[0, 1]],
#
#        [[0, 2]],
#
#        ...,
#
#        [[3, 0]],
#
#        [[2, 0]],
#
#        [[1, 0]]], dtype=int32), array([[[173, 288]],
#
#        [[174, 287]],
#
#        [[175, 288]],
#
#        [[174, 289]]], dtype=int32), array([[[170, 284]],
#
#        [[171, 283]],
#
#        [[172, 284]],
#
#        [[171, 285]]], dtype=int32), array([[[ 38, 146]],
#
#        [[ 39, 145]],
#
#        [[ 40, 146]],
#
#        [[ 39, 147]]], dtype=int32), array([[[ 37, 140]],
#
#        [[ 38, 139]],
#
#        [[ 39, 140]],
#
#        [[ 38, 141]]], dtype=int32), array([[[ 38, 123]],
#
#        [[ 39, 122]],
#
#        [[ 40, 123]],
#
#        [[ 39, 124]]], dtype=int32), array([[[ 38, 117]],
#
#        [[ 39, 116]],
#
#        [[ 40, 117]],
#
#        [[ 39, 118]]], dtype=int32), array([[[ 38, 115]],
#
#        [[ 39, 114]],
#
#        [[ 40, 115]],
#
#        [[ 39, 116]]], dtype=int32), array([[[ 38, 109]],
#
#        [[ 39, 108]],
#
#        [[ 40, 109]],
#
#        [[ 39, 110]]], dtype=int32), array([[[ 39, 107]],
#
#        [[ 40, 106]],
#
#        [[ 41, 107]],
#
#        [[ 40, 108]]], dtype=int32), array([[[ 38, 106]],
#
#        [[ 39, 105]],
#
#        [[ 40, 106]],
#
#        [[ 39, 107]]], dtype=int32), array([[[ 38, 103]],
#
#        [[ 39, 102]],
#
#        [[ 40, 103]],
#
#        [[ 39, 104]]], dtype=int32), array([[[ 37,  99]],
#
#        [[ 38,  98]],
#
#        [[ 39,  99]],
#
#        [[ 40, 100]],
#
#        [[ 40, 101]],
#
#        [[ 39, 102]],
#
#        [[ 38, 103]],
#
#        [[ 37, 102]],
#
#        [[ 37, 101]],
#
#        [[ 37, 100]]], dtype=int32), array([[[38, 92]],
#
#        [[39, 91]],
#
#        [[40, 92]],
#
#        [[39, 93]]], dtype=int32), array([[[39, 91]],
#
#        [[40, 90]],
#
#        [[41, 91]],
#
#        [[40, 92]]], dtype=int32), array([[[38, 90]],
#
#        [[39, 89]],
#
#        [[40, 90]],
#
#        [[39, 91]]], dtype=int32), array([[[39, 85]],
#
#        [[40, 84]],
#
#        [[41, 85]],
#
#        [[40, 86]]], dtype=int32), array([[[38, 84]],
#
#        [[39, 83]],
#
#        [[40, 84]],
#
#        [[39, 85]]], dtype=int32), array([[[38, 74]],
#
#        [[39, 73]],
#
#        [[40, 74]],
#
#        [[39, 75]]], dtype=int32), array([[[38, 68]],
#
#        [[39, 67]],
#
#        [[40, 68]],
#
#        [[39, 69]]], dtype=int32), array([[[39, 64]],
#
#        [[40, 63]],
#
#        [[41, 64]],
#
#        [[40, 65]]], dtype=int32), array([[[39, 62]],
#
#        [[40, 61]],
#
#        [[41, 62]],
#
#        [[40, 63]]], dtype=int32), array([[[39, 55]],
#
#        [[40, 54]],
#
#        [[41, 55]],
#
#        [[40, 56]]], dtype=int32), array([[[39, 53]],
#
#        [[40, 52]],
#
#        [[41, 53]],
#
#        [[40, 54]]], dtype=int32), array([[[37, 48]],
#
#        [[38, 47]],
#
#        [[39, 48]],
#
#        [[38, 49]]], dtype=int32), array([[[39, 30]],
#
#        [[40, 29]],
#
#        [[41, 30]],
#
#        [[40, 31]]], dtype=int32), array([[[36, 27]],
#
#        [[37, 26]],
#
#        [[38, 27]],
#
#        [[38, 28]],
#
#        [[37, 29]],
#
#        [[36, 28]]], dtype=int32), array([[[234,  25]],
#
#        [[235,  24]],
#
#        [[236,  24]],
#
#        [[237,  24]],
#
#        [[238,  25]],
#
#        [[237,  26]],
#
#        [[236,  26]],
#
#        [[235,  26]]], dtype=int32), array([[[231,  25]],
#
#        [[232,  24]],
#
#        [[233,  24]],
#
#        [[234,  25]],
#
#        [[233,  26]],
#
#        [[232,  26]]], dtype=int32), array([[[224,  25]],
#
#        [[225,  24]],
#
#        [[226,  25]],
#
#        [[225,  26]]], dtype=int32), array([[[217,  25]],
#
#        [[218,  24]],
#
#        [[219,  24]],
#
#        [[220,  25]],
#
#        [[219,  26]],
#
#        [[218,  26]]], dtype=int32), array([[[210,  25]],
#
#        [[211,  24]],
#
#        [[212,  25]],
#
#        [[211,  26]]], dtype=int32), array([[[204,  25]],
#
#        [[205,  24]],
#
#        [[206,  25]],
#
#        [[205,  26]]], dtype=int32), array([[[196,  25]],
#
#        [[197,  24]],
#
#        [[198,  25]],
#
#        [[198,  26]],
#
#        [[198,  27]],
#
#        [[197,  28]],
#
#        [[196,  27]],
#
#        [[196,  26]]], dtype=int32), array([[[100,  24]],
#
#        [[101,  23]],
#
#        [[102,  24]],
#
#        [[101,  25]]], dtype=int32), array([[[36, 24]],
#
#        [[37, 23]],
#
#        [[38, 23]],
#
#        ...,
#
#        [[38, 26]],
#
#        [[37, 26]],
#
#        [[36, 25]]], dtype=int32), array([[[206, 286]],
#
#        [[206, 287]],
#
#        [[207, 286]],
#
#        [[208, 286]],
#
#        [[209, 287]],
#
#        [[208, 286]],
#
#        [[207, 286]]], dtype=int32), array([[[178, 286]]], dtype=int32), array([[[164, 286]]], dtype=int32), array([[[136, 286]]], dtype=int32), array([[[120, 286]]], dtype=int32), array([[[106, 286]]], dtype=int32), array([[[ 92, 286]]], dtype=int32), array([[[153, 285]]], dtype=int32), array([[[100, 285]]], dtype=int32), array([[[ 90, 285]]], dtype=int32), array([[[ 86, 285]],
#
#        [[ 87, 285]],
#
#        [[ 88, 285]],
#
#        [[ 87, 285]]], dtype=int32), array([[[ 76, 285]]], dtype=int32), array([[[ 73, 285]],
#
#        [[ 74, 285]]], dtype=int32), array([[[ 60, 285]]], dtype=int32), array([[[ 46, 285]]], dtype=int32), array([[[ 39, 285]]], dtype=int32), array([[[194, 284]]], dtype=int32), array([[[209, 283]],
#
#        [[208, 284]],
#
#        [[209, 283]],
#
#        [[210, 284]],
#
#        [[210, 285]],
#
#        [[211, 286]],
#
#        [[212, 286]],
#
#        [[213, 287]],
#
#        [[214, 286]],
#
#        [[215, 287]],
#
#        [[216, 287]],
#
#        [[217, 286]],
#
#        [[218, 285]],
#
#        [[218, 284]],
#
#        [[219, 283]],
#
#        [[220, 284]],
#
#        [[221, 285]],
#
#        [[220, 286]],
#
#        [[219, 287]],
#
#        [[220, 286]],
#
#        [[221, 285]],
#
#        [[222, 286]],
#
#        [[223, 285]],
#
#        [[224, 286]],
#
#        [[225, 286]],
#
#        [[226, 286]],
#
#        [[227, 287]],
#
#        [[228, 286]],
#
#        [[229, 286]],
#
#        [[230, 287]],
#
#        [[231, 286]],
#
#        [[232, 285]],
#
#        [[233, 284]],
#
#        [[234, 285]],
#
#        [[234, 286]],
#
#        [[233, 287]],
#
#        [[234, 287]],
#
#        [[234, 286]],
#
#        [[235, 285]],
#
#        [[236, 286]],
#
#        [[237, 285]],
#
#        [[238, 286]],
#
#        [[239, 286]],
#
#        [[238, 285]],
#
#        [[237, 285]],
#
#        [[236, 284]],
#
#        [[235, 283]],
#
#        [[234, 284]],
#
#        [[233, 284]],
#
#        [[232, 284]],
#
#        [[231, 285]],
#
#        [[230, 284]],
#
#        [[229, 284]],
#
#        [[228, 284]],
#
#        [[227, 284]],
#
#        [[226, 284]],
#
#        [[225, 285]],
#
#        [[224, 284]],
#
#        [[224, 283]],
#
#        [[224, 284]],
#
#        [[223, 285]],
#
#        [[222, 284]],
#
#        [[221, 283]],
#
#        [[220, 283]],
#
#        [[219, 283]],
#
#        [[218, 284]],
#
#        [[217, 285]],
#
#        [[217, 286]],
#
#        [[216, 287]],
#
#        [[215, 286]],
#
#        [[215, 285]],
#
#        [[215, 284]],
#
#        [[214, 283]],
#
#        [[213, 283]],
#
#        [[212, 283]],
#
#        [[211, 283]],
#
#        [[210, 284]]], dtype=int32), array([[[235, 285]],
#
#        [[236, 284]],
#
#        [[237, 285]],
#
#        [[236, 286]]], dtype=int32), array([[[229, 285]],
#
#        [[230, 284]],
#
#        [[231, 285]],
#
#        [[230, 286]]], dtype=int32), array([[[226, 285]],
#
#        [[227, 284]],
#
#        [[228, 285]],
#
#        [[227, 286]]], dtype=int32), array([[[223, 285]],
#
#        [[224, 284]],
#
#        [[225, 285]],
#
#        [[224, 286]]], dtype=int32), array([[[221, 285]],
#
#        [[222, 284]],
#
#        [[223, 285]],
#
#        [[222, 286]]], dtype=int32), array([[[212, 285]],
#
#        [[213, 284]],
#
#        [[214, 285]],
#
#        [[213, 286]]], dtype=int32), array([[[234, 284]],
#
#        [[235, 283]],
#
#        [[236, 284]],
#
#        [[235, 285]]], dtype=int32), array([[[220, 284]],
#
#        [[221, 283]],
#
#        [[222, 284]],
#
#        [[221, 285]]], dtype=int32), array([[[210, 284]],
#
#        [[211, 283]],
#
#        [[212, 283]],
#
#        [[213, 284]],
#
#        [[212, 285]],
#
#        [[211, 285]]], dtype=int32), array([[[197, 283]],
#
#        [[197, 284]],
#
#        [[196, 285]],
#
#        [[196, 286]],
#
#        [[195, 287]],
#
#        [[194, 286]],
#
#        [[193, 286]],
#
#        [[192, 286]],
#
#        [[193, 286]],
#
#        [[194, 286]],
#
#        [[195, 287]],
#
#        [[196, 286]],
#
#        [[197, 285]],
#
#        [[198, 286]],
#
#        [[198, 285]],
#
#        [[197, 284]],
#
#        [[198, 283]],
#
#        [[199, 283]],
#
#        [[200, 284]],
#
#        [[201, 284]],
#
#        [[202, 285]],
#
#        [[203, 286]],
#
#        [[202, 287]],
#
#        [[201, 287]],
#
#        [[200, 286]],
#
#        [[201, 287]],
#
#        [[202, 287]],
#
#        [[203, 286]],
#
#        [[204, 285]],
#
#        [[203, 284]],
#
#        [[204, 283]],
#
#        [[205, 283]],
#
#        [[206, 284]],
#
#        [[206, 283]],
#
#        [[205, 283]],
#
#        [[204, 283]],
#
#        [[203, 284]],
#
#        [[202, 285]],
#
#        [[201, 284]],
#
#        [[200, 283]],
#
#        [[199, 283]],
#
#        [[198, 283]]], dtype=int32), array([[[202, 285]],
#
#        [[203, 284]],
#
#        [[204, 285]],
#
#        [[203, 286]]], dtype=int32), array([[[184, 283]],
#
#        [[184, 284]],
#
#        [[183, 285]],
#
#        [[182, 285]],
#
#        [[182, 286]],
#
#        [[183, 285]],
#
#        [[184, 285]],
#
#        [[185, 285]],
#
#        [[186, 286]],
#
#        [[187, 287]],
#
#        [[188, 287]],
#
#        [[189, 286]],
#
#        [[188, 285]],
#
#        [[189, 284]],
#
#        [[190, 283]],
#
#        [[191, 283]],
#
#        [[192, 284]],
#
#        [[192, 283]],
#
#        [[191, 283]],
#
#        [[190, 283]],
#
#        [[189, 284]],
#
#        [[188, 285]],
#
#        [[187, 284]],
#
#        [[186, 283]],
#
#        [[185, 283]]], dtype=int32), array([[[185, 285]],
#
#        [[186, 284]],
#
#        [[187, 284]],
#
#        [[188, 285]],
#
#        [[189, 286]],
#
#        [[188, 287]],
#
#        [[187, 287]],
#
#        [[186, 286]]], dtype=int32), array([[[184, 284]],
#
#        [[185, 283]],
#
#        [[186, 284]],
#
#        [[185, 285]]], dtype=int32), array([[[181, 283]],
#
#        [[180, 284]]], dtype=int32), array([[[156, 282]],
#
#        [[156, 283]],
#
#        [[156, 284]],
#
#        [[156, 285]],
#
#        [[157, 285]],
#
#        [[158, 284]],
#
#        [[158, 283]],
#
#        [[159, 282]],
#
#        [[160, 282]],
#
#        [[161, 283]],
#
#        [[161, 284]],
#
#        [[160, 285]],
#
#        [[161, 284]],
#
#        [[162, 283]],
#
#        [[163, 283]],
#
#        [[164, 284]],
#
#        [[164, 283]],
#
#        [[164, 282]],
#
#        [[163, 282]],
#
#        [[162, 282]],
#
#        [[161, 282]],
#
#        [[160, 282]],
#
#        [[159, 282]],
#
#        [[158, 282]],
#
#        [[157, 282]]], dtype=int32), array([[[156, 284]],
#
#        [[157, 283]],
#
#        [[158, 284]],
#
#        [[157, 285]]], dtype=int32), array([[[ 86, 282]],
#
#        [[ 86, 283]],
#
#        [[ 87, 283]],
#
#        [[ 88, 283]],
#
#        [[ 89, 283]],
#
#        [[ 90, 283]],
#
#        [[ 91, 283]],
#
#        [[ 92, 284]],
#
#        [[ 92, 283]],
#
#        [[ 93, 282]],
#
#        [[ 94, 283]],
#
#        [[ 94, 284]],
#
#        [[ 95, 285]],
#
#        [[ 95, 284]],
#
#        [[ 96, 283]],
#
#        [[ 97, 284]],
#
#        [[ 97, 285]],
#
#        [[ 98, 284]],
#
#        [[ 98, 283]],
#
#        [[ 99, 282]],
#
#        [[100, 283]],
#
#        [[101, 283]],
#
#        [[102, 284]],
#
#        [[102, 285]],
#
#        [[103, 284]],
#
#        [[104, 285]],
#
#        [[105, 284]],
#
#        [[106, 284]],
#
#        [[107, 283]],
#
#        [[108, 284]],
#
#        [[109, 285]],
#
#        [[109, 284]],
#
#        [[110, 283]],
#
#        [[111, 284]],
#
#        [[111, 285]],
#
#        [[112, 284]],
#
#        [[112, 283]],
#
#        [[112, 282]],
#
#        [[111, 282]],
#
#        [[110, 282]],
#
#        [[109, 282]],
#
#        [[108, 282]],
#
#        [[107, 282]],
#
#        [[106, 282]],
#
#        [[105, 282]],
#
#        [[104, 282]],
#
#        [[103, 282]],
#
#        [[102, 282]],
#
#        [[101, 282]],
#
#        [[100, 282]],
#
#        [[ 99, 282]],
#
#        [[ 98, 282]],
#
#        [[ 97, 282]],
#
#        [[ 96, 282]],
#
#        [[ 95, 282]],
#
#        [[ 94, 282]],
#
#        [[ 93, 282]],
#
#        [[ 92, 282]],
#
#        [[ 91, 282]],
#
#        [[ 90, 282]],
#
#        [[ 89, 282]],
#
#        [[ 88, 282]],
#
#        [[ 87, 282]]], dtype=int32), array([[[110, 283]],
#
#        [[111, 282]],
#
#        [[112, 283]],
#
#        [[111, 284]]], dtype=int32), array([[[108, 283]],
#
#        [[109, 282]],
#
#        [[110, 283]],
#
#        [[109, 284]]], dtype=int32), array([[[101, 283]],
#
#        [[102, 282]],
#
#        [[103, 283]],
#
#        [[102, 284]]], dtype=int32), array([[[ 96, 283]],
#
#        [[ 97, 282]],
#
#        [[ 98, 283]],
#
#        [[ 97, 284]]], dtype=int32), array([[[ 94, 283]],
#
#        [[ 95, 282]],
#
#        [[ 96, 283]],
#
#        [[ 95, 284]]], dtype=int32), array([[[ 44, 282]],
#
#        [[ 45, 282]],
#
#        [[ 46, 283]],
#
#        [[ 47, 283]],
#
#        [[ 48, 282]],
#
#        [[ 49, 283]],
#
#        [[ 50, 283]],
#
#        [[ 51, 282]],
#
#        [[ 52, 283]],
#
#        [[ 52, 284]],
#
#        [[ 53, 285]],
#
#        [[ 52, 284]],
#
#        [[ 52, 283]],
#
#        [[ 53, 282]],
#
#        [[ 54, 283]],
#
#        [[ 55, 283]],
#
#        [[ 56, 284]],
#
#        [[ 57, 285]],
#
#        [[ 56, 284]],
#
#        [[ 55, 283]],
#
#        [[ 56, 282]],
#
#        [[ 57, 282]],
#
#        [[ 58, 282]],
#
#        [[ 59, 282]],
#
#        [[ 60, 283]],
#
#        [[ 61, 283]],
#
#        [[ 62, 283]],
#
#        [[ 63, 283]],
#
#        [[ 64, 284]],
#
#        [[ 64, 283]],
#
#        [[ 65, 282]],
#
#        [[ 66, 283]],
#
#        [[ 66, 284]],
#
#        [[ 67, 285]],
#
#        [[ 67, 284]],
#
#        [[ 68, 283]],
#
#        [[ 69, 284]],
#
#        [[ 69, 285]],
#
#        [[ 70, 284]],
#
#        [[ 70, 283]],
#
#        [[ 71, 282]],
#
#        [[ 72, 283]],
#
#        [[ 73, 283]],
#
#        [[ 74, 283]],
#
#        [[ 75, 283]],
#
#        [[ 76, 283]],
#
#        [[ 77, 283]],
#
#        [[ 78, 284]],
#
#        [[ 78, 283]],
#
#        [[ 79, 282]],
#
#        [[ 80, 283]],
#
#        [[ 80, 284]],
#
#        [[ 81, 285]],
#
#        [[ 81, 284]],
#
#        [[ 82, 283]],
#
#        [[ 83, 284]],
#
#        [[ 83, 285]],
#
#        [[ 84, 284]],
#
#        [[ 84, 283]],
#
#        [[ 84, 282]],
#
#        [[ 83, 282]],
#
#        [[ 82, 282]],
#
#        [[ 81, 282]],
#
#        [[ 80, 282]],
#
#        [[ 79, 282]],
#
#        [[ 78, 282]],
#
#        [[ 77, 282]],
#
#        [[ 76, 283]],
#
#        [[ 75, 282]],
#
#        [[ 74, 282]],
#
#        [[ 73, 282]],
#
#        [[ 72, 282]],
#
#        [[ 71, 282]],
#
#        [[ 70, 282]],
#
#        [[ 69, 282]],
#
#        [[ 68, 282]],
#
#        [[ 67, 282]],
#
#        [[ 66, 282]],
#
#        [[ 65, 282]],
#
#        [[ 64, 282]],
#
#        [[ 63, 283]],
#
#        [[ 62, 282]],
#
#        [[ 61, 282]],
#
#        [[ 60, 282]],
#
#        [[ 59, 282]],
#
#        [[ 58, 282]],
#
#        [[ 57, 282]],
#
#        [[ 56, 282]],
#
#        [[ 55, 283]],
#
#        [[ 54, 282]],
#
#        [[ 53, 282]],
#
#        [[ 52, 282]],
#
#        [[ 51, 282]],
#
#        [[ 50, 282]],
#
#        [[ 49, 283]],
#
#        [[ 48, 282]],
#
#        [[ 47, 283]],
#
#        [[ 46, 282]],
#
#        [[ 45, 282]]], dtype=int32), array([[[ 80, 283]],
#
#        [[ 81, 282]],
#
#        [[ 82, 283]],
#
#        [[ 81, 284]]], dtype=int32), array([[[ 68, 283]],
#
#        [[ 69, 282]],
#
#        [[ 70, 283]],
#
#        [[ 69, 284]]], dtype=int32), array([[[ 66, 283]],
#
#        [[ 67, 282]],
#
#        [[ 68, 283]],
#
#        [[ 67, 284]]], dtype=int32), array([[[123, 281]],
#
#        [[122, 282]],
#
#        [[121, 282]],
#
#        [[120, 282]],
#
#        [[119, 282]],
#
#        [[118, 282]],
#
#        [[117, 282]],
#
#        [[116, 282]],
#
#        [[115, 282]],
#
#        [[114, 282]],
#
#        [[114, 283]],
#
#        [[114, 284]],
#
#        [[114, 285]],
#
#        [[115, 285]],
#
#        [[116, 285]],
#
#        [[117, 285]],
#
#        [[118, 285]],
#
#        [[119, 284]],
#
#        [[120, 284]],
#
#        [[121, 283]],
#
#        [[122, 284]],
#
#        [[123, 285]],
#
#        [[122, 286]],
#
#        [[123, 285]],
#
#        [[123, 284]],
#
#        [[124, 283]],
#
#        [[125, 284]],
#
#        [[125, 285]],
#
#        [[126, 284]],
#
#        [[126, 283]],
#
#        [[127, 282]],
#
#        [[128, 283]],
#
#        [[128, 284]],
#
#        [[128, 285]],
#
#        [[129, 285]],
#
#        [[130, 284]],
#
#        [[131, 285]],
#
#        [[132, 285]],
#
#        [[133, 286]],
#
#        [[134, 286]],
#
#        [[133, 286]],
#
#        [[132, 285]],
#
#        [[133, 284]],
#
#        [[134, 284]],
#
#        [[135, 283]],
#
#        [[136, 284]],
#
#        [[136, 283]],
#
#        [[137, 282]],
#
#        [[138, 282]],
#
#        [[139, 283]],
#
#        [[139, 284]],
#
#        [[140, 285]],
#
#        [[140, 284]],
#
#        [[140, 283]],
#
#        [[141, 282]],
#
#        [[142, 283]],
#
#        [[143, 283]],
#
#        [[144, 284]],
#
#        [[143, 285]],
#
#        [[142, 285]],
#
#        [[143, 285]],
#
#        [[144, 284]],
#
#        [[145, 285]],
#
#        [[146, 285]],
#
#        [[147, 286]],
#
#        [[148, 286]],
#
#        [[149, 286]],
#
#        [[150, 286]],
#
#        [[149, 286]],
#
#        [[148, 286]],
#
#        [[147, 286]],
#
#        [[146, 285]],
#
#        [[147, 284]],
#
#        [[148, 284]],
#
#        [[149, 283]],
#
#        [[150, 284]],
#
#        [[150, 283]],
#
#        [[151, 282]],
#
#        [[152, 282]],
#
#        [[153, 283]],
#
#        [[154, 283]],
#
#        [[154, 282]],
#
#        [[153, 283]],
#
#        [[152, 282]],
#
#        [[151, 282]],
#
#        [[150, 282]],
#
#        [[149, 282]],
#
#        [[148, 282]],
#
#        [[147, 282]],
#
#        [[146, 282]],
#
#        [[145, 282]],
#
#        [[144, 282]],
#
#        [[143, 282]],
#
#        [[142, 281]],
#
#        [[141, 282]],
#
#        [[140, 282]],
#
#        [[139, 282]],
#
#        [[138, 282]],
#
#        [[137, 281]],
#
#        [[136, 281]],
#
#        [[135, 281]],
#
#        [[134, 281]],
#
#        [[133, 282]],
#
#        [[132, 282]],
#
#        [[131, 281]],
#
#        [[130, 281]],
#
#        [[129, 281]],
#
#        [[128, 281]],
#
#        [[127, 281]],
#
#        [[126, 282]],
#
#        [[125, 281]],
#
#        [[124, 282]]], dtype=int32), array([[[145, 284]],
#
#        [[146, 283]],
#
#        [[147, 284]],
#
#        [[146, 285]]], dtype=int32), array([[[131, 284]],
#
#        [[132, 283]],
#
#        [[133, 284]],
#
#        [[132, 285]]], dtype=int32), array([[[128, 284]],
#
#        [[129, 283]],
#
#        [[130, 284]],
#
#        [[129, 285]]], dtype=int32), array([[[117, 284]],
#
#        [[118, 283]],
#
#        [[119, 284]],
#
#        [[118, 285]]], dtype=int32), array([[[114, 284]],
#
#        [[115, 283]],
#
#        [[116, 284]],
#
#        [[115, 285]]], dtype=int32), array([[[122, 283]],
#
#        [[123, 282]],
#
#        [[124, 283]],
#
#        [[123, 284]]], dtype=int32), array([[[ 37, 281]],
#
#        [[ 37, 282]],
#
#        [[ 38, 281]],
#
#        [[ 39, 282]],
#
#        [[ 39, 283]],
#
#        [[ 40, 282]],
#
#        [[ 41, 283]],
#
#        [[ 42, 284]],
#
#        [[ 41, 283]],
#
#        [[ 42, 282]],
#
#        [[ 41, 283]],
#
#        [[ 40, 282]],
#
#        [[ 39, 282]],
#
#        [[ 38, 281]]], dtype=int32), array([[[205, 280]],
#
#        [[206, 280]],
#
#        [[207, 280]],
#
#        [[208, 280]],
#
#        [[209, 280]],
#
#        [[210, 280]],
#
#        [[211, 280]],
#
#        [[212, 280]],
#
#        [[213, 280]],
#
#        [[214, 280]],
#
#        [[215, 280]],
#
#        [[216, 280]],
#
#        [[217, 280]],
#
#        [[218, 280]],
#
#        [[219, 280]],
#
#        [[220, 280]],
#
#        [[221, 280]],
#
#        [[222, 280]],
#
#        [[223, 280]],
#
#        [[224, 280]],
#
#        [[225, 280]],
#
#        [[226, 280]],
#
#        [[227, 280]],
#
#        [[228, 280]],
#
#        [[229, 280]],
#
#        [[230, 280]],
#
#        [[231, 280]],
#
#        [[230, 280]],
#
#        [[229, 280]],
#
#        [[228, 280]],
#
#        [[227, 280]],
#
#        [[226, 280]],
#
#        [[225, 280]],
#
#        [[224, 280]],
#
#        [[223, 280]],
#
#        [[222, 280]],
#
#        [[221, 280]],
#
#        [[220, 280]],
#
#        [[219, 280]],
#
#        [[218, 280]],
#
#        [[217, 280]],
#
#        [[216, 280]],
#
#        [[215, 280]],
#
#        [[214, 280]],
#
#        [[213, 280]],
#
#        [[212, 280]],
#
#        [[211, 280]],
#
#        [[210, 280]],
#
#        [[209, 280]],
#
#        [[208, 280]],
#
#        [[207, 280]],
#
#        [[206, 280]]], dtype=int32), array([[[202, 280]],
#
#        [[203, 280]]], dtype=int32), array([[[171, 279]],
#
#        [[172, 279]],
#
#        [[173, 279]],
#
#        [[174, 279]],
#
#        [[175, 279]],
#
#        [[176, 279]],
#
#        [[177, 279]],
#
#        [[178, 279]],
#
#        [[177, 279]],
#
#        [[176, 279]],
#
#        [[175, 279]],
#
#        [[174, 279]],
#
#        [[173, 279]],
#
#        [[172, 279]]], dtype=int32), array([[[167, 279]],
#
#        [[168, 279]],
#
#        [[169, 279]],
#
#        [[168, 279]]], dtype=int32), array([[[220, 277]],
#
#        [[219, 278]],
#
#        [[220, 278]],
#
#        [[221, 278]],
#
#        [[222, 278]],
#
#        [[223, 278]],
#
#        [[224, 278]],
#
#        [[225, 277]],
#
#        [[226, 278]],
#
#        [[227, 278]],
#
#        [[228, 278]],
#
#        [[229, 278]],
#
#        [[230, 278]],
#
#        [[231, 278]],
#
#        [[230, 277]],
#
#        [[229, 277]],
#
#        [[228, 278]],
#
#        [[227, 277]],
#
#        [[226, 277]],
#
#        [[225, 277]],
#
#        [[224, 277]],
#
#        [[223, 277]],
#
#        [[222, 277]],
#
#        [[221, 277]]], dtype=int32), array([[[206, 277]],
#
#        [[205, 278]],
#
#        [[206, 278]],
#
#        [[207, 278]],
#
#        [[208, 278]],
#
#        [[209, 278]],
#
#        [[210, 278]],
#
#        [[211, 277]],
#
#        [[212, 278]],
#
#        [[213, 278]],
#
#        [[214, 278]],
#
#        [[215, 278]],
#
#        [[216, 278]],
#
#        [[217, 278]],
#
#        [[216, 277]],
#
#        [[215, 277]],
#
#        [[214, 277]],
#
#        [[213, 277]],
#
#        [[212, 278]],
#
#        [[211, 277]],
#
#        [[210, 278]],
#
#        [[209, 277]],
#
#        [[208, 277]],
#
#        [[207, 278]]], dtype=int32), array([[[199, 277]],
#
#        [[198, 278]],
#
#        [[199, 278]],
#
#        [[200, 278]],
#
#        [[201, 277]],
#
#        [[202, 278]],
#
#        [[203, 278]],
#
#        [[202, 277]],
#
#        [[201, 277]],
#
#        [[200, 277]]], dtype=int32), array([[[192, 277]],
#
#        [[192, 278]],
#
#        [[193, 277]],
#
#        [[194, 277]],
#
#        [[195, 278]],
#
#        [[196, 278]],
#
#        [[196, 277]],
#
#        [[195, 278]],
#
#        [[194, 277]],
#
#        [[193, 277]]], dtype=int32), array([[[189, 277]],
#
#        [[189, 278]]], dtype=int32), array([[[183, 277]],
#
#        [[182, 278]],
#
#        [[181, 278]],
#
#        [[181, 279]],
#
#        [[182, 278]],
#
#        [[183, 277]],
#
#        [[184, 277]],
#
#        [[185, 277]],
#
#        [[186, 277]],
#
#        [[187, 277]],
#
#        [[186, 277]],
#
#        [[185, 277]],
#
#        [[184, 277]]], dtype=int32), array([[[175, 277]],
#
#        [[176, 277]],
#
#        [[177, 277]],
#
#        [[178, 277]],
#
#        [[177, 277]],
#
#        [[176, 277]]], dtype=int32), array([[[167, 277]],
#
#        [[168, 277]],
#
#        [[169, 277]],
#
#        [[170, 277]],
#
#        [[169, 277]],
#
#        [[168, 277]]], dtype=int32), array([[[160, 277]],
#
#        [[161, 277]],
#
#        [[162, 277]],
#
#        [[163, 277]],
#
#        [[162, 277]],
#
#        [[161, 277]]], dtype=int32), array([[[153, 277]],
#
#        [[154, 277]],
#
#        [[155, 277]],
#
#        [[156, 277]],
#
#        [[155, 277]],
#
#        [[154, 277]]], dtype=int32), array([[[145, 277]],
#
#        [[146, 277]],
#
#        [[147, 277]],
#
#        [[148, 277]],
#
#        [[149, 277]],
#
#        [[148, 277]],
#
#        [[147, 277]],
#
#        [[146, 277]]], dtype=int32), array([[[138, 277]],
#
#        [[139, 277]],
#
#        [[140, 277]],
#
#        [[141, 277]],
#
#        [[140, 277]],
#
#        [[139, 277]]], dtype=int32), array([[[134, 277]]], dtype=int32), array([[[130, 277]],
#
#        [[131, 277]],
#
#        [[132, 277]],
#
#        [[131, 277]]], dtype=int32), array([[[127, 277]]], dtype=int32), array([[[122, 277]],
#
#        [[123, 277]],
#
#        [[124, 277]],
#
#        [[125, 277]],
#
#        [[124, 277]],
#
#        [[123, 277]]], dtype=int32), array([[[120, 277]]], dtype=int32), array([[[115, 277]],
#
#        [[116, 277]],
#
#        [[117, 277]],
#
#        [[118, 277]],
#
#        [[117, 277]],
#
#        [[116, 277]]], dtype=int32), array([[[104, 276]],
#
#        [[105, 276]],
#
#        [[106, 276]],
#
#        [[107, 276]],
#
#        [[108, 277]],
#
#        [[109, 277]],
#
#        [[110, 277]],
#
#        [[111, 276]],
#
#        [[110, 277]],
#
#        [[109, 276]],
#
#        [[108, 277]],
#
#        [[107, 276]],
#
#        [[106, 276]],
#
#        [[105, 276]]], dtype=int32), array([[[ 97, 276]],
#
#        [[ 98, 276]],
#
#        [[ 99, 276]],
#
#        [[100, 276]],
#
#        [[101, 277]],
#
#        [[102, 276]],
#
#        [[101, 276]],
#
#        [[100, 276]],
#
#        [[ 99, 276]],
#
#        [[ 98, 276]]], dtype=int32), array([[[ 64, 276]],
#
#        [[ 63, 277]],
#
#        [[ 64, 277]],
#
#        [[ 65, 277]],
#
#        [[ 66, 276]],
#
#        [[ 65, 277]]], dtype=int32), array([[[ 56, 276]],
#
#        [[ 57, 277]],
#
#        [[ 58, 277]],
#
#        [[ 57, 276]]], dtype=int32), array([[[ 50, 276]],
#
#        [[ 50, 277]],
#
#        [[ 51, 277]]], dtype=int32), array([[[185, 275]]], dtype=int32), array([[[179, 275]]], dtype=int32), array([[[175, 275]],
#
#        [[176, 275]]], dtype=int32), array([[[162, 275]]], dtype=int32), array([[[150, 275]]], dtype=int32), array([[[ 72, 275]],
#
#        [[ 71, 276]],
#
#        [[ 70, 276]],
#
#        [[ 70, 277]],
#
#        [[ 71, 277]],
#
#        [[ 72, 277]],
#
#        [[ 73, 277]],
#
#        [[ 74, 276]],
#
#        [[ 75, 275]],
#
#        [[ 76, 276]],
#
#        [[ 77, 277]],
#
#        [[ 78, 276]],
#
#        [[ 79, 277]],
#
#        [[ 80, 277]],
#
#        [[ 81, 276]],
#
#        [[ 82, 275]],
#
#        [[ 83, 275]],
#
#        [[ 84, 276]],
#
#        [[ 84, 277]],
#
#        [[ 85, 277]],
#
#        [[ 86, 277]],
#
#        [[ 87, 277]],
#
#        [[ 88, 276]],
#
#        [[ 89, 276]],
#
#        [[ 90, 276]],
#
#        [[ 91, 277]],
#
#        [[ 92, 276]],
#
#        [[ 93, 277]],
#
#        [[ 94, 277]],
#
#        [[ 95, 276]],
#
#        [[ 94, 276]],
#
#        [[ 93, 277]],
#
#        [[ 92, 276]],
#
#        [[ 91, 277]],
#
#        [[ 90, 276]],
#
#        [[ 89, 275]],
#
#        [[ 88, 275]],
#
#        [[ 87, 275]],
#
#        [[ 86, 275]],
#
#        [[ 85, 275]],
#
#        [[ 84, 275]],
#
#        [[ 83, 275]],
#
#        [[ 82, 275]],
#
#        [[ 81, 275]],
#
#        [[ 80, 275]],
#
#        [[ 79, 275]],
#
#        [[ 78, 275]],
#
#        [[ 77, 275]],
#
#        [[ 76, 275]],
#
#        [[ 75, 275]],
#
#        [[ 74, 275]],
#
#        [[ 73, 275]]], dtype=int32), array([[[190, 274]]], dtype=int32), array([[[192, 273]]], dtype=int32), array([[[162, 273]]], dtype=int32), array([[[125, 273]],
#
#        [[125, 274]]], dtype=int32), array([[[ 38, 273]],
#
#        [[ 38, 274]],
#
#        [[ 37, 275]],
#
#        [[ 38, 276]],
#
#        [[ 38, 277]],
#
#        [[ 37, 278]],
#
#        [[ 36, 277]],
#
#        [[ 37, 278]],
#
#        [[ 38, 277]],
#
#        [[ 38, 276]],
#
#        [[ 37, 275]],
#
#        [[ 38, 274]]], dtype=int32), array([[[188, 272]],
#
#        [[187, 273]],
#
#        [[188, 274]],
#
#        [[187, 275]],
#
#        [[188, 274]],
#
#        [[187, 273]]], dtype=int32), array([[[184, 272]],
#
#        [[184, 273]],
#
#        [[185, 272]]], dtype=int32), array([[[182, 272]]], dtype=int32), array([[[176, 272]]], dtype=int32), array([[[165, 272]],
#
#        [[165, 273]],
#
#        [[165, 274]],
#
#        [[165, 275]],
#
#        [[165, 274]],
#
#        [[165, 273]]], dtype=int32), array([[[160, 272]],
#
#        [[159, 273]],
#
#        [[159, 274]],
#
#        [[160, 274]],
#
#        [[159, 273]]], dtype=int32), array([[[157, 272]],
#
#        [[156, 273]],
#
#        [[155, 274]],
#
#        [[154, 273]],
#
#        [[153, 274]],
#
#        [[153, 275]],
#
#        [[154, 274]],
#
#        [[155, 275]],
#
#        [[155, 274]],
#
#        [[156, 273]]], dtype=int32), array([[[151, 272]]], dtype=int32), array([[[125, 271]]], dtype=int32), array([[[ 35, 270]]], dtype=int32), array([[[ 79, 266]]], dtype=int32), array([[[ 37, 266]],
#
#        [[ 36, 267]],
#
#        [[ 37, 267]],
#
#        [[ 38, 268]],
#
#        [[ 37, 269]],
#
#        [[ 38, 270]],
#
#        [[ 37, 271]],
#
#        [[ 36, 272]],
#
#        [[ 35, 272]],
#
#        [[ 36, 272]],
#
#        [[ 37, 271]],
#
#        [[ 38, 271]],
#
#        [[ 38, 270]],
#
#        [[ 38, 269]],
#
#        [[ 38, 268]],
#
#        [[ 38, 267]]], dtype=int32), array([[[ 81, 265]]], dtype=int32), array([[[104, 264]]], dtype=int32), array([[[ 75, 263]]], dtype=int32), array([[[ 67, 263]],
#
#        [[ 68, 263]]], dtype=int32), array([[[ 54, 263]]], dtype=int32), array([[[200, 262]]], dtype=int32), array([[[115, 262]]], dtype=int32), array([[[104, 262]]], dtype=int32), array([[[232, 261]]], dtype=int32), array([[[212, 261]]], dtype=int32), array([[[ 36, 261]],
#
#        [[ 35, 262]]], dtype=int32), array([[[232, 259]]], dtype=int32), array([[[225, 259]]], dtype=int32), array([[[163, 259]]], dtype=int32), array([[[ 72, 259]]], dtype=int32), array([[[ 36, 259]]], dtype=int32), array([[[168, 258]]], dtype=int32), array([[[143, 258]]], dtype=int32), array([[[145, 257]],
#
#        [[145, 258]]], dtype=int32), array([[[ 38, 257]],
#
#        [[ 38, 258]],
#
#        [[ 38, 259]],
#
#        [[ 38, 260]],
#
#        [[ 38, 261]],
#
#        [[ 38, 262]],
#
#        [[ 37, 263]],
#
#        [[ 38, 263]],
#
#        [[ 38, 262]],
#
#        [[ 38, 261]],
#
#        [[ 38, 260]],
#
#        [[ 38, 259]],
#
#        [[ 38, 258]]], dtype=int32), array([[[172, 256]]], dtype=int32), array([[[ 73, 256]]], dtype=int32), array([[[181, 255]]], dtype=int32), array([[[174, 255]],
#
#        [[175, 255]],
#
#        [[176, 255]],
#
#        [[177, 255]],
#
#        [[178, 255]],
#
#        [[177, 255]],
#
#        [[176, 255]],
#
#        [[175, 255]]], dtype=int32), array([[[ 76, 255]]], dtype=int32), array([[[ 71, 255]]], dtype=int32), array([[[ 35, 255]]], dtype=int32), array([[[232, 254]],
#
#        [[232, 255]]], dtype=int32), array([[[188, 254]],
#
#        [[189, 254]],
#
#        [[190, 254]],
#
#        [[191, 254]],
#
#        [[192, 254]],
#
#        [[193, 254]],
#
#        [[192, 254]],
#
#        [[191, 254]],
#
#        [[190, 254]],
#
#        [[189, 254]]], dtype=int32), array([[[184, 254]]], dtype=int32), array([[[196, 253]]], dtype=int32), array([[[173, 253]]], dtype=int32), array([[[ 62, 252]]], dtype=int32), array([[[ 37, 252]],
#
#        [[ 38, 253]],
#
#        [[ 38, 254]],
#
#        [[ 37, 255]],
#
#        [[ 38, 255]],
#
#        [[ 38, 254]],
#
#        [[ 38, 253]]], dtype=int32), array([[[232, 251]],
#
#        [[232, 252]]], dtype=int32), array([[[175, 251]]], dtype=int32), array([[[ 93, 250]]], dtype=int32), array([[[ 91, 250]],
#
#        [[ 90, 251]],
#
#        [[ 89, 252]],
#
#        [[ 88, 252]],
#
#        [[ 89, 252]],
#
#        [[ 90, 251]],
#
#        [[ 91, 251]]], dtype=int32), array([[[200, 248]],
#
#        [[199, 249]],
#
#        [[198, 250]],
#
#        [[197, 251]],
#
#        [[198, 250]],
#
#        [[199, 249]]], dtype=int32), array([[[177, 247]],
#
#        [[176, 248]],
#
#        [[177, 247]],
#
#        [[178, 247]]], dtype=int32), array([[[107, 247]],
#
#        [[108, 247]]], dtype=int32), array([[[103, 247]],
#
#        [[103, 248]]], dtype=int32), array([[[ 38, 247]],
#
#        [[ 38, 248]],
#
#        [[ 37, 249]],
#
#        [[ 36, 248]],
#
#        [[ 37, 249]],
#
#        [[ 36, 250]],
#
#        [[ 37, 249]],
#
#        [[ 38, 249]],
#
#        [[ 38, 248]]], dtype=int32), array([[[122, 246]]], dtype=int32), array([[[ 93, 246]]], dtype=int32), array([[[ 87, 246]]], dtype=int32), array([[[232, 245]],
#
#        [[232, 246]],
#
#        [[232, 247]],
#
#        [[232, 248]],
#
#        [[232, 247]],
#
#        [[232, 246]]], dtype=int32), array([[[119, 245]],
#
#        [[119, 246]]], dtype=int32), array([[[ 81, 245]]], dtype=int32), array([[[ 37, 244]],
#
#        [[ 37, 245]],
#
#        [[ 38, 245]],
#
#        [[ 38, 244]]], dtype=int32), array([[[202, 243]],
#
#        [[201, 244]]], dtype=int32), array([[[122, 243]]], dtype=int32), array([[[204, 242]],
#
#        [[205, 242]]], dtype=int32), array([[[169, 242]]], dtype=int32), array([[[160, 241]],
#
#        [[161, 241]],
#
#        [[162, 241]],
#
#        [[161, 241]]], dtype=int32), array([[[ 80, 241]]], dtype=int32), array([[[ 37, 241]],
#
#        [[ 36, 242]]], dtype=int32), array([[[164, 240]]], dtype=int32), array([[[ 61, 240]],
#
#        [[ 62, 241]]], dtype=int32), array([[[178, 239]]], dtype=int32), array([[[176, 239]],
#
#        [[176, 240]]], dtype=int32), array([[[173, 239]]], dtype=int32), array([[[147, 239]],
#
#        [[148, 239]],
#
#        [[149, 239]],
#
#        [[150, 239]],
#
#        [[151, 239]],
#
#        [[152, 239]],
#
#        [[153, 239]],
#
#        [[154, 239]],
#
#        [[155, 239]],
#
#        [[156, 239]],
#
#        [[157, 240]],
#
#        [[156, 239]],
#
#        [[155, 239]],
#
#        [[154, 239]],
#
#        [[153, 239]],
#
#        [[152, 239]],
#
#        [[151, 239]],
#
#        [[150, 239]],
#
#        [[149, 239]],
#
#        [[148, 239]]], dtype=int32), array([[[ 44, 239]],
#
#        [[ 44, 240]],
#
#        [[ 44, 241]],
#
#        [[ 44, 240]]], dtype=int32), array([[[ 35, 239]],
#
#        [[ 35, 240]]], dtype=int32), array([[[182, 238]]], dtype=int32), array([[[180, 238]]], dtype=int32), array([[[133, 238]],
#
#        [[134, 238]],
#
#        [[135, 238]],
#
#        [[136, 238]],
#
#        [[137, 238]],
#
#        [[138, 238]],
#
#        [[139, 238]],
#
#        [[140, 238]],
#
#        [[139, 238]],
#
#        [[138, 238]],
#
#        [[137, 238]],
#
#        [[136, 238]],
#
#        [[135, 238]],
#
#        [[134, 238]]], dtype=int32), array([[[131, 238]]], dtype=int32), array([[[ 38, 238]],
#
#        [[ 37, 239]],
#
#        [[ 38, 239]],
#
#        [[ 39, 240]],
#
#        [[ 39, 241]],
#
#        [[ 39, 240]],
#
#        [[ 39, 239]]], dtype=int32), array([[[232, 237]],
#
#        [[232, 238]],
#
#        [[232, 239]],
#
#        [[232, 240]],
#
#        [[232, 241]],
#
#        [[232, 240]],
#
#        [[232, 239]],
#
#        [[232, 238]]], dtype=int32), array([[[184, 237]]], dtype=int32), array([[[ 61, 237]],
#
#        [[ 61, 238]]], dtype=int32), array([[[208, 236]],
#
#        [[207, 237]],
#
#        [[206, 238]],
#
#        [[205, 239]],
#
#        [[206, 238]],
#
#        [[207, 237]]], dtype=int32), array([[[186, 236]],
#
#        [[186, 237]]], dtype=int32), array([[[ 36, 236]]], dtype=int32), array([[[210, 235]]], dtype=int32), array([[[135, 234]]], dtype=int32), array([[[ 36, 234]]], dtype=int32), array([[[170, 233]]], dtype=int32), array([[[128, 233]],
#
#        [[128, 234]]], dtype=int32), array([[[100, 233]]], dtype=int32), array([[[179, 232]],
#
#        [[179, 233]],
#
#        [[178, 234]],
#
#        [[177, 234]],
#
#        [[178, 234]],
#
#        [[179, 233]]], dtype=int32), array([[[176, 232]]], dtype=int32), array([[[ 94, 232]]], dtype=int32), array([[[232, 231]],
#
#        [[232, 232]],
#
#        [[232, 233]],
#
#        [[232, 232]]], dtype=int32), array([[[192, 231]],
#
#        [[192, 232]],
#
#        [[191, 233]],
#
#        [[190, 234]],
#
#        [[189, 235]],
#
#        [[188, 236]],
#
#        [[189, 236]],
#
#        [[189, 235]],
#
#        [[190, 234]],
#
#        [[191, 233]],
#
#        [[192, 232]]], dtype=int32), array([[[117, 231]]], dtype=int32), array([[[ 79, 231]],
#
#        [[ 78, 232]],
#
#        [[ 77, 232]],
#
#        [[ 76, 233]],
#
#        [[ 76, 234]],
#
#        [[ 76, 235]],
#
#        [[ 75, 236]],
#
#        [[ 76, 236]],
#
#        [[ 76, 235]],
#
#        [[ 77, 234]],
#
#        [[ 76, 233]],
#
#        [[ 77, 232]],
#
#        [[ 78, 232]],
#
#        [[ 79, 231]],
#
#        [[ 80, 232]],
#
#        [[ 81, 232]],
#
#        [[ 82, 232]],
#
#        [[ 81, 231]],
#
#        [[ 80, 231]]], dtype=int32), array([[[ 44, 231]],
#
#        [[ 44, 232]],
#
#        [[ 44, 233]],
#
#        [[ 44, 234]],
#
#        [[ 44, 233]],
#
#        [[ 44, 232]]], dtype=int32), array([[[206, 230]]], dtype=int32), array([[[194, 230]],
#
#        [[194, 231]]], dtype=int32), array([[[104, 230]],
#
#        [[103, 231]]], dtype=int32), array([[[ 36, 228]]], dtype=int32), array([[[195, 227]],
#
#        [[195, 228]]], dtype=int32), array([[[240, 226]]], dtype=int32), array([[[197, 226]],
#
#        [[198, 226]]], dtype=int32), array([[[ 36, 226]]], dtype=int32), array([[[200, 225]]], dtype=int32), array([[[ 44, 225]],
#
#        [[ 44, 226]],
#
#        [[ 44, 227]],
#
#        [[ 45, 226]],
#
#        [[ 45, 225]]], dtype=int32), array([[[232, 224]],
#
#        [[232, 225]],
#
#        [[232, 226]],
#
#        [[232, 225]]], dtype=int32), array([[[226, 223]]], dtype=int32), array([[[208, 223]]], dtype=int32), array([[[ 37, 223]],
#
#        [[ 36, 224]],
#
#        [[ 37, 223]],
#
#        [[ 38, 224]],
#
#        [[ 38, 225]],
#
#        [[ 39, 226]],
#
#        [[ 39, 227]],
#
#        [[ 38, 228]],
#
#        [[ 39, 229]],
#
#        [[ 38, 230]],
#
#        [[ 37, 230]],
#
#        [[ 37, 231]],
#
#        [[ 38, 230]],
#
#        [[ 39, 231]],
#
#        [[ 39, 232]],
#
#        [[ 38, 233]],
#
#        [[ 38, 234]],
#
#        [[ 38, 235]],
#
#        [[ 38, 236]],
#
#        [[ 39, 235]],
#
#        [[ 39, 234]],
#
#        [[ 39, 233]],
#
#        [[ 39, 232]],
#
#        [[ 39, 231]],
#
#        [[ 38, 230]],
#
#        [[ 39, 229]],
#
#        [[ 39, 228]],
#
#        [[ 39, 227]],
#
#        [[ 39, 226]],
#
#        [[ 39, 225]],
#
#        [[ 38, 224]],
#
#        [[ 38, 223]]], dtype=int32), array([[[213, 222]]], dtype=int32), array([[[211, 222]]], dtype=int32), array([[[180, 222]]], dtype=int32), array([[[ 42, 222]],
#
#        [[ 42, 223]],
#
#        [[ 42, 224]],
#
#        [[ 42, 223]]], dtype=int32), array([[[215, 221]],
#
#        [[216, 221]]], dtype=int32), array([[[188, 220]]], dtype=int32), array([[[ 36, 220]]], dtype=int32), array([[[182, 219]],
#
#        [[182, 220]],
#
#        [[183, 219]]], dtype=int32), array([[[ 39, 219]],
#
#        [[ 39, 220]],
#
#        [[ 38, 221]],
#
#        [[ 39, 221]],
#
#        [[ 39, 220]]], dtype=int32), array([[[186, 218]]], dtype=int32), array([[[232, 217]],
#
#        [[232, 218]],
#
#        [[232, 219]],
#
#        [[232, 218]]], dtype=int32), array([[[228, 217]]], dtype=int32), array([[[103, 217]]], dtype=int32), array([[[ 44, 217]],
#
#        [[ 44, 218]],
#
#        [[ 44, 219]],
#
#        [[ 45, 219]],
#
#        [[ 45, 218]],
#
#        [[ 45, 217]]], dtype=int32), array([[[101, 215]]], dtype=int32), array([[[ 77, 215]],
#
#        [[ 78, 216]]], dtype=int32), array([[[ 36, 214]]], dtype=int32), array([[[240, 212]]], dtype=int32), array([[[132, 212]],
#
#        [[132, 213]]], dtype=int32), array([[[ 92, 212]],
#
#        [[ 92, 213]],
#
#        [[ 92, 214]],
#
#        [[ 92, 213]]], dtype=int32), array([[[ 36, 212]]], dtype=int32), array([[[191, 210]]], dtype=int32), array([[[ 45, 210]],
#
#        [[ 44, 211]],
#
#        [[ 44, 212]],
#
#        [[ 45, 212]],
#
#        [[ 45, 211]]], dtype=int32), array([[[192, 208]]], dtype=int32), array([[[ 90, 207]]], dtype=int32), array([[[ 72, 207]],
#
#        [[ 71, 208]]], dtype=int32), array([[[196, 206]]], dtype=int32), array([[[187, 205]]], dtype=int32), array([[[ 77, 205]]], dtype=int32), array([[[ 39, 205]],
#
#        [[ 38, 206]],
#
#        [[ 37, 206]],
#
#        [[ 38, 207]],
#
#        [[ 37, 208]],
#
#        [[ 36, 209]],
#
#        [[ 35, 208]],
#
#        [[ 36, 209]],
#
#        [[ 37, 209]],
#
#        [[ 38, 210]],
#
#        [[ 39, 211]],
#
#        [[ 38, 212]],
#
#        [[ 38, 213]],
#
#        [[ 38, 214]],
#
#        [[ 38, 215]],
#
#        [[ 37, 216]],
#
#        [[ 37, 217]],
#
#        [[ 36, 218]],
#
#        [[ 37, 217]],
#
#        [[ 38, 216]],
#
#        [[ 39, 216]],
#
#        [[ 39, 215]],
#
#        [[ 39, 214]],
#
#        [[ 39, 213]],
#
#        [[ 39, 212]],
#
#        [[ 39, 211]],
#
#        [[ 38, 210]],
#
#        [[ 37, 209]],
#
#        [[ 37, 208]],
#
#        [[ 38, 207]],
#
#        [[ 39, 207]],
#
#        [[ 39, 206]]], dtype=int32), array([[[ 73, 204]]], dtype=int32), array([[[ 69, 203]],
#
#        [[ 68, 204]]], dtype=int32), array([[[ 45, 203]],
#
#        [[ 45, 204]]], dtype=int32), array([[[ 38, 202]],
#
#        [[ 37, 203]],
#
#        [[ 38, 202]],
#
#        [[ 39, 203]],
#
#        [[ 39, 202]]], dtype=int32), array([[[218, 201]]], dtype=int32), array([[[ 84, 201]]], dtype=int32), array([[[ 72, 201]]], dtype=int32), array([[[122, 200]],
#
#        [[121, 201]],
#
#        [[122, 201]]], dtype=int32), array([[[ 61, 199]]], dtype=int32), array([[[240, 198]],
#
#        [[240, 199]]], dtype=int32), array([[[ 79, 198]]], dtype=int32), array([[[ 36, 197]],
#
#        [[ 36, 198]]], dtype=int32), array([[[218, 195]]], dtype=int32), array([[[ 83, 195]]], dtype=int32), array([[[ 81, 195]],
#
#        [[ 81, 196]]], dtype=int32), array([[[231, 194]]], dtype=int32), array([[[ 89, 194]]], dtype=int32), array([[[ 86, 194]]], dtype=int32), array([[[ 77, 194]]], dtype=int32), array([[[ 65, 194]]], dtype=int32), array([[[238, 193]]], dtype=int32), array([[[215, 193]]], dtype=int32), array([[[ 81, 193]]], dtype=int32), array([[[ 45, 192]],
#
#        [[ 45, 193]],
#
#        [[ 45, 194]],
#
#        [[ 45, 195]],
#
#        [[ 45, 196]],
#
#        [[ 45, 197]],
#
#        [[ 45, 196]],
#
#        [[ 45, 195]],
#
#        [[ 45, 194]],
#
#        [[ 45, 193]]], dtype=int32), array([[[240, 191]]], dtype=int32), array([[[ 89, 191]],
#
#        [[ 89, 192]]], dtype=int32), array([[[ 86, 191]],
#
#        [[ 86, 192]]], dtype=int32), array([[[ 82, 191]]], dtype=int32), array([[[ 39, 191]],
#
#        [[ 38, 192]],
#
#        [[ 37, 192]],
#
#        [[ 38, 193]],
#
#        [[ 37, 194]],
#
#        [[ 38, 195]],
#
#        [[ 38, 196]],
#
#        [[ 39, 197]],
#
#        [[ 38, 198]],
#
#        [[ 38, 199]],
#
#        [[ 37, 200]],
#
#        [[ 38, 199]],
#
#        [[ 39, 199]],
#
#        [[ 39, 198]],
#
#        [[ 39, 197]],
#
#        [[ 39, 196]],
#
#        [[ 38, 195]],
#
#        [[ 39, 194]],
#
#        [[ 39, 193]],
#
#        [[ 39, 192]]], dtype=int32), array([[[ 37, 194]],
#
#        [[ 38, 193]],
#
#        [[ 39, 194]],
#
#        [[ 38, 195]]], dtype=int32), array([[[134, 188]],
#
#        [[135, 188]],
#
#        [[136, 189]],
#
#        [[137, 188]],
#
#        [[136, 189]],
#
#        [[135, 188]]], dtype=int32), array([[[123, 188]],
#
#        [[124, 188]]], dtype=int32), array([[[ 88, 188]]], dtype=int32), array([[[ 50, 188]]], dtype=int32), array([[[ 38, 188]],
#
#        [[ 37, 189]],
#
#        [[ 38, 189]],
#
#        [[ 39, 189]],
#
#        [[ 39, 188]]], dtype=int32), array([[[231, 187]]], dtype=int32), array([[[198, 187]]], dtype=int32), array([[[145, 187]]], dtype=int32), array([[[142, 187]],
#
#        [[143, 188]],
#
#        [[143, 187]]], dtype=int32), array([[[ 92, 187]]], dtype=int32), array([[[134, 185]],
#
#        [[134, 186]]], dtype=int32), array([[[125, 185]]], dtype=int32), array([[[ 89, 185]],
#
#        [[ 89, 186]]], dtype=int32), array([[[ 45, 185]],
#
#        [[ 45, 186]],
#
#        [[ 45, 187]],
#
#        [[ 45, 188]],
#
#        [[ 45, 189]],
#
#        [[ 45, 188]],
#
#        [[ 45, 187]],
#
#        [[ 45, 186]]], dtype=int32), array([[[240, 183]],
#
#        [[240, 184]],
#
#        [[240, 185]],
#
#        [[240, 184]]], dtype=int32), array([[[191, 182]],
#
#        [[191, 183]]], dtype=int32), array([[[ 51, 182]]], dtype=int32), array([[[ 89, 181]],
#
#        [[ 88, 182]]], dtype=int32), array([[[ 64, 181]]], dtype=int32), array([[[231, 180]]], dtype=int32), array([[[200, 180]]], dtype=int32), array([[[ 60, 180]]], dtype=int32), array([[[129, 178]]], dtype=int32), array([[[ 37, 177]],
#
#        [[ 37, 178]],
#
#        [[ 37, 179]],
#
#        [[ 37, 180]],
#
#        [[ 36, 181]],
#
#        [[ 37, 180]],
#
#        [[ 38, 181]],
#
#        [[ 39, 182]],
#
#        [[ 38, 183]],
#
#        [[ 37, 184]],
#
#        [[ 36, 183]],
#
#        [[ 36, 184]],
#
#        [[ 37, 184]],
#
#        [[ 38, 185]],
#
#        [[ 37, 186]],
#
#        [[ 38, 185]],
#
#        [[ 39, 185]],
#
#        [[ 38, 184]],
#
#        [[ 39, 183]],
#
#        [[ 40, 183]],
#
#        [[ 39, 182]],
#
#        [[ 39, 181]],
#
#        [[ 39, 180]],
#
#        [[ 40, 179]],
#
#        [[ 40, 178]],
#
#        [[ 40, 177]],
#
#        [[ 39, 177]],
#
#        [[ 38, 177]]], dtype=int32), array([[[ 37, 180]],
#
#        [[ 38, 179]],
#
#        [[ 39, 180]],
#
#        [[ 38, 181]]], dtype=int32), array([[[ 37, 178]],
#
#        [[ 38, 177]],
#
#        [[ 39, 178]],
#
#        [[ 38, 179]]], dtype=int32), array([[[128, 176]]], dtype=int32), array([[[ 62, 176]]], dtype=int32), array([[[ 45, 176]],
#
#        [[ 45, 177]],
#
#        [[ 45, 178]],
#
#        [[ 45, 179]],
#
#        [[ 45, 180]],
#
#        [[ 45, 181]],
#
#        [[ 45, 180]],
#
#        [[ 45, 179]],
#
#        [[ 45, 178]],
#
#        [[ 45, 177]]], dtype=int32), array([[[197, 175]]], dtype=int32), array([[[161, 175]]], dtype=int32), array([[[ 72, 175]]], dtype=int32), array([[[ 51, 175]]], dtype=int32), array([[[121, 174]],
#
#        [[122, 175]],
#
#        [[123, 176]],
#
#        [[122, 175]],
#
#        [[122, 174]]], dtype=int32), array([[[ 85, 174]]], dtype=int32), array([[[149, 173]],
#
#        [[148, 174]],
#
#        [[147, 175]],
#
#        [[147, 176]],
#
#        [[146, 177]],
#
#        [[147, 176]],
#
#        [[147, 175]],
#
#        [[148, 174]]], dtype=int32), array([[[146, 170]],
#
#        [[146, 171]],
#
#        [[146, 172]],
#
#        [[146, 173]],
#
#        [[146, 172]],
#
#        [[146, 171]]], dtype=int32), array([[[135, 170]]], dtype=int32), array([[[132, 170]]], dtype=int32), array([[[240, 169]],
#
#        [[240, 170]],
#
#        [[240, 171]],
#
#        [[240, 170]]], dtype=int32), array([[[210, 169]]], dtype=int32), array([[[157, 169]],
#
#        [[157, 170]]], dtype=int32), array([[[ 88, 169]],
#
#        [[ 89, 169]]], dtype=int32), array([[[ 36, 169]],
#
#        [[ 36, 170]]], dtype=int32), array([[[197, 168]]], dtype=int32), array([[[153, 168]],
#
#        [[153, 169]]], dtype=int32), array([[[ 45, 168]],
#
#        [[ 45, 169]],
#
#        [[ 45, 170]],
#
#        [[ 45, 171]],
#
#        [[ 45, 172]],
#
#        [[ 45, 171]],
#
#        [[ 46, 170]],
#
#        [[ 45, 169]]], dtype=int32), array([[[188, 167]],
#
#        [[188, 168]]], dtype=int32), array([[[131, 167]],
#
#        [[131, 168]],
#
#        [[132, 168]]], dtype=int32), array([[[ 36, 167]]], dtype=int32), array([[[154, 166]]], dtype=int32), array([[[210, 165]],
#
#        [[210, 166]],
#
#        [[211, 167]],
#
#        [[212, 168]],
#
#        [[212, 167]],
#
#        [[211, 167]],
#
#        [[210, 166]]], dtype=int32), array([[[198, 165]]], dtype=int32), array([[[187, 165]]], dtype=int32), array([[[138, 165]],
#
#        [[137, 166]],
#
#        [[138, 167]],
#
#        [[139, 168]],
#
#        [[138, 169]],
#
#        [[137, 170]],
#
#        [[138, 169]],
#
#        [[139, 168]],
#
#        [[140, 169]],
#
#        [[140, 170]],
#
#        [[139, 171]],
#
#        [[140, 170]],
#
#        [[140, 169]],
#
#        [[141, 168]],
#
#        [[141, 167]],
#
#        [[140, 167]],
#
#        [[139, 168]],
#
#        [[138, 167]],
#
#        [[138, 166]]], dtype=int32), array([[[139, 168]],
#
#        [[140, 167]],
#
#        [[141, 168]],
#
#        [[140, 169]]], dtype=int32), array([[[133, 165]]], dtype=int32), array([[[129, 165]],
#
#        [[129, 166]],
#
#        [[128, 167]],
#
#        [[129, 166]]], dtype=int32), array([[[ 86, 165]],
#
#        [[ 87, 166]],
#
#        [[ 88, 166]],
#
#        [[ 87, 166]]], dtype=int32), array([[[238, 164]]], dtype=int32), array([[[232, 164]],
#
#        [[232, 165]]], dtype=int32), array([[[163, 164]],
#
#        [[162, 165]],
#
#        [[162, 166]],
#
#        [[162, 167]],
#
#        [[162, 168]],
#
#        [[162, 167]],
#
#        [[163, 166]],
#
#        [[163, 165]]], dtype=int32), array([[[157, 164]],
#
#        [[158, 164]],
#
#        [[159, 164]],
#
#        [[158, 164]]], dtype=int32), array([[[195, 163]]], dtype=int32), array([[[ 38, 163]],
#
#        [[ 37, 164]],
#
#        [[ 37, 165]],
#
#        [[ 38, 165]],
#
#        [[ 39, 166]],
#
#        [[ 38, 167]],
#
#        [[ 39, 168]],
#
#        [[ 38, 169]],
#
#        [[ 39, 169]],
#
#        [[ 40, 170]],
#
#        [[ 39, 171]],
#
#        [[ 38, 171]],
#
#        [[ 37, 172]],
#
#        [[ 38, 172]],
#
#        [[ 39, 173]],
#
#        [[ 38, 174]],
#
#        [[ 37, 174]],
#
#        [[ 37, 175]],
#
#        [[ 38, 175]],
#
#        [[ 39, 175]],
#
#        [[ 40, 175]],
#
#        [[ 39, 174]],
#
#        [[ 40, 173]],
#
#        [[ 40, 172]],
#
#        [[ 40, 171]],
#
#        [[ 40, 170]],
#
#        [[ 40, 169]],
#
#        [[ 39, 168]],
#
#        [[ 39, 167]],
#
#        [[ 39, 166]],
#
#        [[ 40, 165]],
#
#        [[ 40, 164]],
#
#        [[ 40, 163]],
#
#        [[ 39, 163]]], dtype=int32), array([[[ 38, 172]],
#
#        [[ 39, 171]],
#
#        [[ 40, 172]],
#
#        [[ 39, 173]]], dtype=int32), array([[[ 37, 164]],
#
#        [[ 38, 163]],
#
#        [[ 39, 164]],
#
#        [[ 38, 165]]], dtype=int32), array([[[238, 162]]], dtype=int32), array([[[168, 162]],
#
#        [[167, 163]]], dtype=int32), array([[[165, 162]]], dtype=int32), array([[[128, 162]]], dtype=int32), array([[[109, 162]]], dtype=int32), array([[[ 75, 162]]], dtype=int32), array([[[ 67, 161]]], dtype=int32), array([[[209, 160]],
#
#        [[209, 161]],
#
#        [[208, 162]],
#
#        [[208, 163]],
#
#        [[208, 164]],
#
#        [[209, 163]],
#
#        [[210, 163]],
#
#        [[209, 163]],
#
#        [[208, 162]],
#
#        [[209, 161]]], dtype=int32), array([[[195, 160]]], dtype=int32), array([[[151, 160]],
#
#        [[151, 161]],
#
#        [[151, 162]],
#
#        [[152, 162]],
#
#        [[152, 161]]], dtype=int32), array([[[137, 160]]], dtype=int32), array([[[129, 160]],
#
#        [[130, 161]],
#
#        [[130, 162]],
#
#        [[130, 163]],
#
#        [[130, 162]],
#
#        [[130, 161]]], dtype=int32), array([[[ 87, 160]]], dtype=int32), array([[[ 45, 160]],
#
#        [[ 45, 161]],
#
#        [[ 45, 162]],
#
#        [[ 45, 163]],
#
#        [[ 45, 164]],
#
#        [[ 45, 165]],
#
#        [[ 45, 164]],
#
#        [[ 45, 163]],
#
#        [[ 45, 162]],
#
#        [[ 45, 161]]], dtype=int32), array([[[218, 159]],
#
#        [[217, 160]],
#
#        [[216, 160]],
#
#        [[215, 161]],
#
#        [[214, 161]],
#
#        [[213, 161]],
#
#        [[214, 162]],
#
#        [[215, 161]],
#
#        [[216, 161]],
#
#        [[217, 160]],
#
#        [[218, 161]],
#
#        [[217, 160]],
#
#        [[218, 159]],
#
#        [[219, 159]]], dtype=int32), array([[[135, 159]],
#
#        [[134, 160]],
#
#        [[133, 161]],
#
# ...
#
#        [[228,  60]],
#
#        [[228,  59]],
#
#        [[228,  58]],
#
#        [[227,  57]],
#
#        [[228,  56]],
#
#        [[227,  55]],
#
#        [[228,  54]],
#
#        [[228,  53]],
#
#        [[228,  52]],
#
#        [[228,  51]],
#
#        [[228,  50]],
#
#        [[227,  50]],
#
#        [[226,  49]],
#
#        [[225,  48]],
#
#        [[225,  47]],
#
#        [[226,  46]],
#
#        [[226,  45]],
#
#        [[225,  44]],
#
#        [[226,  43]],
#
#        [[226,  42]],
#
#        [[227,  41]]], dtype=int32), array([[[224, 202]],
#
#        [[225, 201]],
#
#        [[226, 202]],
#
#        [[225, 203]]], dtype=int32), array([[[225, 185]],
#
#        [[226, 184]],
#
#        [[227, 184]],
#
#        [[228, 185]],
#
#        [[227, 186]],
#
#        [[226, 186]]], dtype=int32), array([[[224, 183]],
#
#        [[225, 182]],
#
#        [[226, 183]],
#
#        [[225, 184]]], dtype=int32), array([[[224, 165]],
#
#        [[225, 164]],
#
#        [[226, 164]],
#
#        [[227, 165]],
#
#        [[226, 166]],
#
#        [[225, 166]]], dtype=int32), array([[[225, 157]],
#
#        [[226, 156]],
#
#        [[227, 157]],
#
#        [[226, 158]]], dtype=int32), array([[[224, 136]],
#
#        [[225, 135]],
#
#        [[226, 136]],
#
#        [[225, 137]]], dtype=int32), array([[[225, 110]],
#
#        [[226, 109]],
#
#        [[227, 110]],
#
#        [[226, 111]]], dtype=int32), array([[[224,  92]],
#
#        [[225,  91]],
#
#        [[226,  91]],
#
#        [[227,  92]],
#
#        [[227,  93]],
#
#        [[226,  94]],
#
#        [[225,  93]]], dtype=int32), array([[[225,  86]],
#
#        [[226,  85]],
#
#        [[227,  86]],
#
#        [[226,  87]]], dtype=int32), array([[[225,  76]],
#
#        [[226,  75]],
#
#        [[227,  76]],
#
#        [[226,  77]]], dtype=int32), array([[[226,  75]],
#
#        [[227,  74]],
#
#        [[228,  75]],
#
#        [[227,  76]]], dtype=int32), array([[[226,  73]],
#
#        [[227,  72]],
#
#        [[228,  73]],
#
#        [[227,  74]]], dtype=int32), array([[[224,  62]],
#
#        [[225,  61]],
#
#        [[226,  62]],
#
#        [[225,  63]]], dtype=int32), array([[[224,  41]]], dtype=int32), array([[[222,  41]]], dtype=int32), array([[[213,  41]],
#
#        [[214,  41]],
#
#        [[215,  41]],
#
#        [[216,  41]],
#
#        [[217,  41]],
#
#        [[216,  41]],
#
#        [[215,  41]],
#
#        [[214,  41]]], dtype=int32), array([[[211,  41]]], dtype=int32), array([[[208,  41]]], dtype=int32), array([[[197,  41]]], dtype=int32), array([[[195,  41]]], dtype=int32), array([[[172,  40]],
#
#        [[171,  41]],
#
#        [[170,  41]],
#
#        [[169,  41]],
#
#        [[168,  41]],
#
#        [[167,  41]],
#
#        [[166,  41]],
#
#        [[165,  41]],
#
#        [[164,  41]],
#
#        [[163,  41]],
#
#        [[162,  41]],
#
#        [[161,  41]],
#
#        [[160,  41]],
#
#        [[159,  41]],
#
#        [[158,  41]],
#
#        [[157,  41]],
#
#        [[156,  41]],
#
#        [[155,  41]],
#
#        [[154,  41]],
#
#        [[153,  41]],
#
#        [[152,  41]],
#
#        [[151,  41]],
#
#        [[150,  41]],
#
#        [[149,  41]],
#
#        [[148,  41]],
#
#        [[147,  41]],
#
#        [[146,  41]],
#
#        [[145,  41]],
#
#        [[144,  41]],
#
#        [[143,  41]],
#
#        [[142,  41]],
#
#        [[141,  41]],
#
#        [[140,  41]],
#
#        [[139,  41]],
#
#        [[138,  41]],
#
#        [[137,  41]],
#
#        [[136,  41]],
#
#        [[135,  41]],
#
#        [[134,  41]],
#
#        [[133,  41]],
#
#        [[132,  41]],
#
#        [[131,  41]],
#
#        [[130,  41]],
#
#        [[129,  41]],
#
#        [[128,  41]],
#
#        [[127,  41]],
#
#        [[126,  41]],
#
#        [[125,  41]],
#
#        [[124,  41]],
#
#        [[123,  41]],
#
#        [[122,  41]],
#
#        [[121,  41]],
#
#        [[120,  41]],
#
#        [[119,  41]],
#
#        [[118,  41]],
#
#        [[117,  41]],
#
#        [[116,  41]],
#
#        [[115,  41]],
#
#        [[114,  41]],
#
#        [[113,  41]],
#
#        [[112,  41]],
#
#        [[111,  41]],
#
#        [[110,  41]],
#
#        [[109,  41]],
#
#        [[108,  41]],
#
#        [[107,  41]],
#
#        [[106,  41]],
#
#        [[105,  41]],
#
#        [[104,  41]],
#
#        [[103,  41]],
#
#        [[102,  41]],
#
#        [[101,  41]],
#
#        [[100,  41]],
#
#        [[ 99,  41]],
#
#        [[ 98,  41]],
#
#        [[ 97,  41]],
#
#        [[ 96,  41]],
#
#        [[ 95,  41]],
#
#        [[ 94,  41]],
#
#        [[ 93,  41]],
#
#        [[ 92,  41]],
#
#        [[ 91,  41]],
#
#        [[ 90,  41]],
#
#        [[ 89,  41]],
#
#        [[ 88,  41]],
#
#        [[ 87,  41]],
#
#        [[ 86,  41]],
#
#        [[ 85,  41]],
#
#        [[ 84,  41]],
#
#        [[ 83,  41]],
#
#        [[ 82,  41]],
#
#        [[ 81,  41]],
#
#        [[ 80,  41]],
#
#        [[ 79,  41]],
#
#        [[ 78,  41]],
#
#        [[ 77,  41]],
#
#        [[ 76,  41]],
#
#        [[ 75,  41]],
#
#        [[ 74,  41]],
#
#        [[ 73,  41]],
#
#        [[ 72,  41]],
#
#        [[ 73,  41]],
#
#        [[ 74,  41]],
#
#        [[ 75,  41]],
#
#        [[ 76,  41]],
#
#        [[ 77,  41]],
#
#        [[ 78,  41]],
#
#        [[ 79,  41]],
#
#        [[ 80,  41]],
#
#        [[ 81,  41]],
#
#        [[ 82,  41]],
#
#        [[ 83,  41]],
#
#        [[ 84,  41]],
#
#        [[ 85,  41]],
#
#        [[ 86,  41]],
#
#        [[ 87,  41]],
#
#        [[ 88,  41]],
#
#        [[ 89,  41]],
#
#        [[ 90,  41]],
#
#        [[ 91,  41]],
#
#        [[ 92,  41]],
#
#        [[ 93,  41]],
#
#        [[ 94,  41]],
#
#        [[ 95,  41]],
#
#        [[ 96,  41]],
#
#        [[ 97,  41]],
#
#        [[ 98,  41]],
#
#        [[ 99,  41]],
#
#        [[100,  41]],
#
#        [[101,  41]],
#
#        [[102,  41]],
#
#        [[103,  41]],
#
#        [[104,  41]],
#
#        [[105,  41]],
#
#        [[106,  41]],
#
#        [[107,  41]],
#
#        [[108,  41]],
#
#        [[109,  41]],
#
#        [[110,  41]],
#
#        [[111,  41]],
#
#        [[112,  41]],
#
#        [[113,  41]],
#
#        [[114,  41]],
#
#        [[115,  41]],
#
#        [[116,  41]],
#
#        [[117,  41]],
#
#        [[118,  41]],
#
#        [[119,  41]],
#
#        [[120,  41]],
#
#        [[121,  41]],
#
#        [[122,  41]],
#
#        [[123,  41]],
#
#        [[124,  41]],
#
#        [[125,  41]],
#
#        [[126,  41]],
#
#        [[127,  41]],
#
#        [[128,  41]],
#
#        [[129,  41]],
#
#        [[130,  41]],
#
#        [[131,  41]],
#
#        [[132,  41]],
#
#        [[133,  41]],
#
#        [[134,  41]],
#
#        [[135,  41]],
#
#        [[136,  41]],
#
#        [[137,  41]],
#
#        [[138,  41]],
#
#        [[139,  41]],
#
#        [[140,  41]],
#
#        [[141,  41]],
#
#        [[142,  41]],
#
#        [[143,  41]],
#
#        [[144,  41]],
#
#        [[145,  41]],
#
#        [[146,  41]],
#
#        [[147,  41]],
#
#        [[148,  41]],
#
#        [[149,  41]],
#
#        [[150,  41]],
#
#        [[151,  41]],
#
#        [[152,  41]],
#
#        [[153,  41]],
#
#        [[154,  41]],
#
#        [[155,  41]],
#
#        [[156,  41]],
#
#        [[157,  41]],
#
#        [[158,  41]],
#
#        [[159,  41]],
#
#        [[160,  41]],
#
#        [[161,  41]],
#
#        [[162,  41]],
#
#        [[163,  41]],
#
#        [[164,  41]],
#
#        [[165,  41]],
#
#        [[166,  41]],
#
#        [[167,  41]],
#
#        [[168,  41]],
#
#        [[169,  41]],
#
#        [[170,  41]],
#
#        [[171,  41]],
#
#        [[172,  41]],
#
#        [[173,  41]],
#
#        [[174,  41]],
#
#        [[175,  41]],
#
#        [[176,  41]],
#
#        [[177,  41]],
#
#        [[178,  41]],
#
#        [[179,  41]],
#
#        [[180,  41]],
#
#        [[181,  41]],
#
#        [[182,  41]],
#
#        [[183,  41]],
#
#        [[184,  41]],
#
#        [[185,  41]],
#
#        [[186,  41]],
#
#        [[187,  41]],
#
#        [[186,  41]],
#
#        [[185,  41]],
#
#        [[184,  41]],
#
#        [[183,  41]],
#
#        [[182,  41]],
#
#        [[181,  41]],
#
#        [[180,  41]],
#
#        [[179,  41]],
#
#        [[178,  41]],
#
#        [[177,  40]],
#
#        [[176,  41]],
#
#        [[175,  41]],
#
#        [[174,  40]],
#
#        [[173,  41]]], dtype=int32), array([[[232,  39]],
#
#        [[232,  40]]], dtype=int32), array([[[239,  36]]], dtype=int32), array([[[46, 36]],
#
#        [[46, 37]],
#
#        [[46, 38]],
#
#        [[46, 39]],
#
#        [[46, 40]],
#
#        [[46, 41]],
#
#        [[46, 42]],
#
#        [[46, 41]],
#
#        [[46, 40]],
#
#        [[46, 39]],
#
#        [[46, 38]],
#
#        [[46, 37]]], dtype=int32), array([[[38, 35]]], dtype=int32), array([[[229,  34]],
#
#        [[230,  35]],
#
#        [[231,  36]],
#
#        [[232,  37]],
#
#        [[231,  36]],
#
#        [[230,  35]],
#
#        [[231,  34]],
#
#        [[230,  34]]], dtype=int32), array([[[210,  34]],
#
#        [[210,  35]],
#
#        [[211,  35]]], dtype=int32), array([[[187,  34]],
#
#        [[188,  34]],
#
#        [[189,  35]],
#
#        [[190,  34]],
#
#        [[191,  34]],
#
#        [[190,  34]],
#
#        [[189,  34]],
#
#        [[188,  34]]], dtype=int32), array([[[171,  34]],
#
#        [[172,  35]],
#
#        [[173,  34]],
#
#        [[174,  34]],
#
#        [[175,  35]],
#
#        [[176,  34]],
#
#        [[175,  34]],
#
#        [[174,  34]],
#
#        [[173,  34]],
#
#        [[172,  34]]], dtype=int32), array([[[168,  34]],
#
#        [[169,  34]]], dtype=int32), array([[[161,  34]],
#
#        [[162,  35]],
#
#        [[163,  34]],
#
#        [[164,  34]],
#
#        [[165,  35]],
#
#        [[166,  34]],
#
#        [[165,  34]],
#
#        [[164,  34]],
#
#        [[163,  34]],
#
#        [[162,  34]]], dtype=int32), array([[[154,  34]],
#
#        [[154,  35]],
#
#        [[155,  35]],
#
#        [[156,  35]],
#
#        [[157,  34]],
#
#        [[158,  35]],
#
#        [[158,  34]],
#
#        [[157,  34]],
#
#        [[156,  34]],
#
#        [[155,  34]]], dtype=int32), array([[[146,  34]],
#
#        [[147,  34]],
#
#        [[148,  35]],
#
#        [[149,  34]],
#
#        [[150,  34]],
#
#        [[149,  34]],
#
#        [[148,  34]],
#
#        [[147,  34]]], dtype=int32), array([[[137,  34]],
#
#        [[138,  35]],
#
#        [[139,  34]],
#
#        [[140,  34]],
#
#        [[141,  34]],
#
#        [[142,  34]],
#
#        [[141,  34]],
#
#        [[140,  34]],
#
#        [[139,  34]],
#
#        [[138,  34]]], dtype=int32), array([[[135,  34]]], dtype=int32), array([[[128,  34]],
#
#        [[128,  35]],
#
#        [[129,  34]],
#
#        [[130,  34]],
#
#        [[131,  35]],
#
#        [[132,  34]],
#
#        [[131,  34]],
#
#        [[130,  34]],
#
#        [[129,  34]]], dtype=int32), array([[[123,  34]],
#
#        [[124,  34]]], dtype=int32), array([[[120,  34]],
#
#        [[121,  34]]], dtype=int32), array([[[112,  34]],
#
#        [[113,  34]]], dtype=int32), array([[[240,  33]],
#
#        [[240,  34]]], dtype=int32), array([[[220,  33]],
#
#        [[221,  34]],
#
#        [[222,  34]],
#
#        [[223,  35]],
#
#        [[224,  34]],
#
#        [[223,  34]],
#
#        [[222,  34]],
#
#        [[221,  33]]], dtype=int32), array([[[212,  33]],
#
#        [[213,  34]],
#
#        [[213,  35]],
#
#        [[214,  34]],
#
#        [[215,  34]],
#
#        [[216,  35]],
#
#        [[217,  34]],
#
#        [[216,  33]],
#
#        [[215,  34]],
#
#        [[214,  33]],
#
#        [[213,  33]]], dtype=int32), array([[[202,  33]],
#
#        [[203,  33]],
#
#        [[204,  33]],
#
#        [[205,  34]],
#
#        [[206,  35]],
#
#        [[207,  34]],
#
#        [[208,  34]],
#
#        [[208,  33]],
#
#        [[207,  34]],
#
#        [[206,  34]],
#
#        [[205,  33]],
#
#        [[204,  33]],
#
#        [[203,  33]]], dtype=int32), array([[[194,  33]],
#
#        [[195,  33]],
#
#        [[196,  34]],
#
#        [[196,  35]],
#
#        [[197,  34]],
#
#        [[198,  34]],
#
#        [[199,  35]],
#
#        [[199,  34]],
#
#        [[198,  33]],
#
#        [[197,  34]],
#
#        [[196,  33]],
#
#        [[195,  33]]], dtype=int32), array([[[185,  33]],
#
#        [[184,  34]],
#
#        [[183,  34]],
#
#        [[182,  34]],
#
#        [[181,  34]],
#
#        [[180,  34]],
#
#        [[179,  35]],
#
#        [[180,  34]],
#
#        [[181,  34]],
#
#        [[182,  35]],
#
#        [[183,  34]],
#
#        [[184,  34]]], dtype=int32), array([[[167,  32]]], dtype=int32), array([[[159,  32]]], dtype=int32), array([[[ 44,  32]],
#
#        [[ 44,  33]],
#
#        [[ 44,  34]],
#
#        [[ 44,  35]],
#
#        [[ 44,  36]],
#
#        [[ 44,  37]],
#
#        [[ 44,  38]],
#
#        [[ 44,  39]],
#
#        [[ 44,  40]],
#
#        [[ 44,  41]],
#
#        [[ 44,  42]],
#
#        [[ 44,  43]],
#
#        [[ 44,  44]],
#
#        [[ 44,  45]],
#
#        [[ 44,  46]],
#
#        [[ 44,  47]],
#
#        [[ 44,  48]],
#
#        [[ 44,  49]],
#
#        [[ 44,  50]],
#
#        [[ 44,  51]],
#
#        [[ 44,  52]],
#
#        [[ 44,  53]],
#
#        [[ 44,  54]],
#
#        [[ 44,  55]],
#
#        [[ 44,  56]],
#
#        [[ 44,  57]],
#
#        [[ 44,  58]],
#
#        [[ 44,  59]],
#
#        [[ 44,  60]],
#
#        [[ 44,  61]],
#
#        [[ 44,  62]],
#
#        [[ 44,  63]],
#
#        [[ 44,  64]],
#
#        [[ 44,  65]],
#
#        [[ 44,  66]],
#
#        [[ 44,  67]],
#
#        [[ 44,  68]],
#
#        [[ 44,  69]],
#
#        [[ 44,  70]],
#
#        [[ 44,  71]],
#
#        [[ 44,  72]],
#
#        [[ 44,  73]],
#
#        [[ 44,  74]],
#
#        [[ 44,  75]],
#
#        [[ 44,  76]],
#
#        [[ 44,  77]],
#
#        [[ 44,  78]],
#
#        [[ 44,  79]],
#
#        [[ 44,  80]],
#
#        [[ 44,  81]],
#
#        [[ 44,  82]],
#
#        [[ 44,  83]],
#
#        [[ 44,  84]],
#
#        [[ 44,  85]],
#
#        [[ 44,  86]],
#
#        [[ 44,  87]],
#
#        [[ 44,  88]],
#
#        [[ 44,  89]],
#
#        [[ 44,  90]],
#
#        [[ 44,  91]],
#
#        [[ 44,  92]],
#
#        [[ 44,  93]],
#
#        [[ 44,  94]],
#
#        [[ 44,  95]],
#
#        [[ 44,  96]],
#
#        [[ 44,  97]],
#
#        [[ 44,  98]],
#
#        [[ 44,  99]],
#
#        [[ 44, 100]],
#
#        [[ 44, 101]],
#
#        [[ 44, 102]],
#
#        [[ 44, 103]],
#
#        [[ 44, 104]],
#
#        [[ 44, 105]],
#
#        [[ 44, 106]],
#
#        [[ 44, 107]],
#
#        [[ 44, 108]],
#
#        [[ 44, 109]],
#
#        [[ 44, 110]],
#
#        [[ 44, 111]],
#
#        [[ 44, 112]],
#
#        [[ 44, 113]],
#
#        [[ 44, 112]],
#
#        [[ 44, 111]],
#
#        [[ 44, 110]],
#
#        [[ 44, 109]],
#
#        [[ 44, 108]],
#
#        [[ 44, 107]],
#
#        [[ 44, 106]],
#
#        [[ 44, 105]],
#
#        [[ 44, 104]],
#
#        [[ 44, 103]],
#
#        [[ 44, 102]],
#
#        [[ 44, 101]],
#
#        [[ 44, 100]],
#
#        [[ 44,  99]],
#
#        [[ 44,  98]],
#
#        [[ 44,  97]],
#
#        [[ 44,  96]],
#
#        [[ 44,  95]],
#
#        [[ 44,  94]],
#
#        [[ 44,  93]],
#
#        [[ 44,  92]],
#
#        [[ 44,  91]],
#
#        [[ 44,  90]],
#
#        [[ 44,  89]],
#
#        [[ 44,  88]],
#
#        [[ 44,  87]],
#
#        [[ 44,  86]],
#
#        [[ 44,  85]],
#
#        [[ 44,  84]],
#
#        [[ 44,  83]],
#
#        [[ 44,  82]],
#
#        [[ 44,  81]],
#
#        [[ 44,  80]],
#
#        [[ 44,  79]],
#
#        [[ 44,  78]],
#
#        [[ 44,  77]],
#
#        [[ 44,  76]],
#
#        [[ 44,  75]],
#
#        [[ 44,  74]],
#
#        [[ 44,  73]],
#
#        [[ 44,  72]],
#
#        [[ 44,  71]],
#
#        [[ 44,  70]],
#
#        [[ 44,  69]],
#
#        [[ 44,  68]],
#
#        [[ 44,  67]],
#
#        [[ 44,  66]],
#
#        [[ 44,  65]],
#
#        [[ 44,  64]],
#
#        [[ 44,  63]],
#
#        [[ 44,  62]],
#
#        [[ 44,  61]],
#
#        [[ 44,  60]],
#
#        [[ 44,  59]],
#
#        [[ 44,  58]],
#
#        [[ 44,  57]],
#
#        [[ 44,  56]],
#
#        [[ 44,  55]],
#
#        [[ 44,  54]],
#
#        [[ 44,  53]],
#
#        [[ 44,  52]],
#
#        [[ 44,  51]],
#
#        [[ 44,  50]],
#
#        [[ 44,  49]],
#
#        [[ 44,  48]],
#
#        [[ 44,  47]],
#
#        [[ 44,  46]],
#
#        [[ 44,  45]],
#
#        [[ 44,  44]],
#
#        [[ 44,  43]],
#
#        [[ 44,  42]],
#
#        [[ 44,  41]],
#
#        [[ 44,  40]],
#
#        [[ 44,  39]],
#
#        [[ 44,  38]],
#
#        [[ 44,  37]],
#
#        [[ 44,  36]],
#
#        [[ 44,  35]],
#
#        [[ 44,  34]],
#
#        [[ 44,  33]]], dtype=int32), array([[[37, 32]],
#
#        [[37, 33]],
#
#        [[38, 33]]], dtype=int32), array([[[239,  28]]], dtype=int32), array([[[211,  28]]], dtype=int32), array([[[215,  27]]], dtype=int32), array([[[201,  27]]], dtype=int32), array([[[187,  27]]], dtype=int32), array([[[146,  27]]], dtype=int32), array([[[132,  27]]], dtype=int32), array([[[113,  27]]], dtype=int32), array([[[89, 27]]], dtype=int32), array([[[182,  26]],
#
#        [[181,  27]],
#
#        [[182,  27]]], dtype=int32), array([[[178,  26]]], dtype=int32), array([[[167,  26]],
#
#        [[168,  27]]], dtype=int32), array([[[164,  26]],
#
#        [[165,  26]]], dtype=int32), array([[[152,  26]],
#
#        [[153,  26]],
#
#        [[154,  27]],
#
#        [[153,  26]]], dtype=int32), array([[[150,  26]]], dtype=int32), array([[[141,  26]]], dtype=int32), array([[[127,  26]],
#
#        [[127,  27]]], dtype=int32), array([[[123,  26]]], dtype=int32), array([[[109,  26]]], dtype=int32), array([[[107,  26]]], dtype=int32), array([[[92, 26]]], dtype=int32), array([[[60, 25]],
#
#        [[61, 25]]], dtype=int32), array([[[46, 25]]], dtype=int32))

# %%
image_copy = image.copy()
image_copy = cv2.drawContours(image_copy, contours, -1, (0, 255, 0), thickness=2, lineType=cv2.LINE_AA)

# %%
cv2.imshow('Grayscale Image', gray)
cv2.imshow('Drawn Contours', image_copy)
cv2.imshow('Binary Image', binary)

cv2.waitKey(0)
cv2.destroyAllWindows()
